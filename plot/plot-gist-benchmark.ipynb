# %%
import pandas as pd

df = pd.read_csv('../results/gist-benchmark.csv')
df['method'] = 'top_block_range'

threshold_df = pd.read_csv('../results/gist-benchmark-threshold.csv')
threshold_df['method'] = 'threshold'

# %%
plot_df = pd.concat([df, threshold_df])

plot_df.head()
# Out:
#    query_time  recall  g_range  l_range           method  threshold
# 0    0.070439  0.0822        3      1.0  top_block_range        NaN
# 1    0.117711  0.1344        3      3.0  top_block_range        NaN
# 2    0.141512  0.1470        3      5.0  top_block_range        NaN
# 3    0.149145  0.1485        3      7.0  top_block_range        NaN
# 4    0.112041  0.1212        5      1.0  top_block_range        NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(data=plot_df, x="recall", y="query_time", hue="method")
# Out:
# <Axes: xlabel='recall', ylabel='query_time'>

# %%
# sns.lineplot(data=df.query('g_range > 13'), x="recall", y="query_time", hue="g_range", palette=["red", "blue", "green", "purple"])
df["block_range"] = df["l_range"]
df["search_range"] = df["g_range"]
ax = sns.barplot(data=df.query('search_range > 13'), x="block_range", y="recall", hue="search_range")
ax.set(xlabel='block_range', ylabel='recall')
plt.show()

# %%
threshold_df["search_range"] = threshold_df["g_range"]
ax = sns.barplot(data=threshold_df.query('search_range > 13'), x="threshold", y="recall", hue="search_range")
ax.set( ylabel='recall')
plt.show()

# %%
ax = sns.lineplot(data=plot_df.query('g_range == 23'), x="recall", y="query_time", hue="method")
ax.set( xlabel='recall', ylabel='query_time (s)')
plt.show()

# %%
plot_df.query('g_range == 23')
# Out:
#     query_time  recall  g_range  l_range           method  threshold
# 32    0.383579  0.4268       23      1.0  top_block_range        NaN
# 33    0.613424  0.6677       23      3.0  top_block_range        NaN
# 34    0.723861  0.7141       23      5.0  top_block_range        NaN
# 35    0.770358  0.7275       23      7.0  top_block_range        NaN
# 32    0.410580  0.5377       23      NaN        threshold       0.50
# 33    0.640602  0.6940       23      NaN        threshold       0.10
# 34    0.681262  0.7080       23      NaN        threshold       0.07
# 35    0.715525  0.7173       23      NaN        threshold       0.05
